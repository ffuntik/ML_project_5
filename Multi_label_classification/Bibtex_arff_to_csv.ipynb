# %%
import arff2pandas
import pandas as pd
from arff2pandas import a2p

# %%
with open('bibtex-train.arff') as f:
    df = a2p.load(f)
    df.to_csv('bibtex-train.csv', index = False)

# %%
with open('bibtex-test.arff') as f:
    df = a2p.load(f)
    df.to_csv('bibtex-test.csv', index = False)
